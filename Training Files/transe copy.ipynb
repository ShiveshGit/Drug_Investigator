# %%
# !pip install pykeen
# Out:
# Requirement already satisfied: pykeen in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.11.0)
# Requirement already satisfied: dataclasses-json in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.6.7)
# Requirement already satisfied: numpy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (1.11.4)
# Requirement already satisfied: click in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (8.1.8)
# Requirement already satisfied: click-default-group in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (1.2.4)
# Requirement already satisfied: scikit-learn in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (1.3.2)
# Requirement already satisfied: torch>=2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (4.67.1)
# Requirement already satisfied: requests in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (2.32.3)
# Requirement already satisfied: optuna>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (4.1.0)
# Requirement already satisfied: pandas>=1.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (2.1.4)
# Requirement already satisfied: tabulate in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.9.0)
# Requirement already satisfied: more-click in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.1.2)
# Requirement already satisfied: more-itertools in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (10.5.0)
# Requirement already satisfied: pystow>=0.4.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.6.1)
# Requirement already satisfied: docdata in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.0.4)
# Requirement already satisfied: class-resolver>=0.5.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.5.4)
# Requirement already satisfied: pyyaml in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (6.0.2)
# Requirement already satisfied: torch-max-mem>=0.1.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.1.3)
# Requirement already satisfied: torch-ppr>=0.0.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (0.0.8)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pykeen) (4.12.2)
# Requirement already satisfied: alembic>=1.5.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (1.14.0)
# Requirement already satisfied: colorlog in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from optuna>=2.0.0->pykeen) (2.0.37)
# Requirement already satisfied: python-dateutil>=2.8.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.0.0->pykeen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.0.0->pykeen) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.0.0->pykeen) (2024.2)
# Requirement already satisfied: filelock in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (3.16.1)
# Requirement already satisfied: sympy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (1.13.3)
# Requirement already satisfied: networkx in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (3.4.2)
# Requirement already satisfied: jinja2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (3.1.5)
# Requirement already satisfied: fsspec in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from torch>=2.0->pykeen) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0->pykeen) (12.6.85)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from dataclasses-json->pykeen) (3.25.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from dataclasses-json->pykeen) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->pykeen) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->pykeen) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->pykeen) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->pykeen) (2024.12.14)
# Requirement already satisfied: joblib>=1.1.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scikit-learn->pykeen) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scikit-learn->pykeen) (3.5.0)
# Requirement already satisfied: Mako in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.3.8)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from jinja2->torch>=2.0->pykeen) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy->torch>=2.0->pykeen) (1.3.0)

# %%
import os.path as osp
import pandas as pd
import torch
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score
from torch_geometric.nn import Node2Vec
from torch_geometric.utils import negative_sampling
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
df = pd.read_csv("./DTO_cleaned.csv")
df = df.replace("","\n",regex=True)

# %%
def write_to_file(data, file_path, separator='`'):
    """
    Write data to a file iteratively.

    Parameters:
        data (list of lists): Data to be written (row-wise).
        file_path (str): Path to the output file.
        separator (str): Separator for columns.
    """
    with open(file_path, 'w') as file:  # Open in write mode
        for _, row in data.iterrows():  # Iterate over each row in the DataFrame
            line = separator.join(map(str, row))  # Convert row values to strings and join with separator
            file.write(line + '\n')  # Write the line and add a newline
write_to_file(df, './train1.txt')

# %%
import csv

def check_file(input_file, output_file):
    """
    Reads a .csv file, splits each line by `, and writes only those lines with exactly 3 elements to a new .csv file.

    Parameters:
        input_file (str): Path to the input .csv file.
        output_file (str): Path to the output .csv file.
    """
    with open(input_file, 'r') as infile, open(output_file, 'w', newline='') as outfile:
        reader = csv.reader(infile, delimiter='`')  # Read lines split by backtick
        writer = csv.writer(outfile, delimiter='\t')  # Write lines split by backtick
        cnt =0
        tot =0
        for row in reader:
            if len(row) == 3:  # Check if the row has exactly 3 elements
                writer.writerow(row)  # Write valid rows to the output file
            else:
                cnt+=1
            tot+=1
                # print(row)
        print(cnt, f'for {input_file}', tot)
        

check_file('./train1.txt','./train.txt')
# Out:
# 684 for ./train1.txt 123219

# %%
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline

TRIPLES_PATH = "./train.txt"
tf = TriplesFactory.from_path(TRIPLES_PATH, create_inverse_triples = True)
training, testing, validation = tf.split([.8, .1, .1])

result = pipeline(
    training = training,
    testing = testing,
    validation = validation,
    model = 'tucker',
    stopper = 'early',
    epochs = 100,
)
#CooccurrenceFiltered
result.save_to_directory('./resultsTU/')
# Out:
# WARNING:pykeen.utils:using automatically assigned random_state=1737525738
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [14344, 12253, 12254]
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 564290574.
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.stoppers.early_stopping:Inferred checkpoint path for best model weights: /teamspace/studios/this_studio/.data/pykeen/checkpoints/best-model-weights-b1730e2a-a435-40c5-940a-6bbdfed2d6ce.pt
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# INFO:pykeen.training.training_loop:Dropping last (incomplete) batch each epoch (1/765 (0.13%) batches).
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.83s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 10: 0.24383874653174473. Saved model weights to /teamspace/studios/this_studio/.data/pykeen/checkpoints/best-model-weights-b1730e2a-a435-40c5-940a-6bbdfed2d6ce.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 10.
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.83s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 20: 0.35363962787661174. Saved model weights to /teamspace/studios/this_studio/.data/pykeen/checkpoints/best-model-weights-b1730e2a-a435-40c5-940a-6bbdfed2d6ce.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 20.
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.81s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 30: 0.3723682062999837. Saved model weights to /teamspace/studios/this_studio/.data/pykeen/checkpoints/best-model-weights-b1730e2a-a435-40c5-940a-6bbdfed2d6ce.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 30.
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.82s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 40: 0.38260976007834174. Saved model weights to /teamspace/studios/this_studio/.data/pykeen/checkpoints/best-model-weights-b1730e2a-a435-40c5-940a-6bbdfed2d6ce.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 40.
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.82s seconds
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.82s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 60: 0.38738371144116207. Saved model weights to /teamspace/studios/this_studio/.data/pykeen/checkpoints/best-model-weights-b1730e2a-a435-40c5-940a-6bbdfed2d6ce.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 60.
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.82s seconds
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/765 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.82s seconds
# INFO:pykeen.stoppers.early_stopping:Stopping early at epoch 80. The best result 0.38738371144116207 occurred at epoch 60.
# INFO:pykeen.stoppers.early_stopping:Re-loading weights from best epoch from /teamspace/studios/this_studio/.data/pykeen/checkpoints/best-model-weights-b1730e2a-a435-40c5-940a-6bbdfed2d6ce.pt
# Evaluating on cuda:0:   0%|          | 0.00/12.3k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 22.94s seconds
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=83717, num_relations=1024, create_inverse_triples=True, num_triples=98028, path="/teamspace/studios/this_studio/train.txt") to file:///teamspace/studios/this_studio/resultsTU/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: /teamspace/studios/this_studio/resultsTU

# %%
# model

# %%
from pykeen.models import ERModel
from pykeen.pipeline import pipeline

# train a model
# result = pipeline(model="TransE", dataset="nations")
model = result.model
# assert isinstance(model, ERModel)

# access entity and relation representations
entity_representation_modules = model.entity_representations
relation_representation_modules = model.relation_representations

# %%
entity_representation_modules
# Out:
# ModuleList(
#   (0): Embedding(
#     (_embeddings): Embedding(83717, 200)
#   )
# )
