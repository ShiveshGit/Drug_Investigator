# %%
! pip install tensorboard

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

# Path to the TensorBoard file
log_file = "events.out.tfevents.1736345242.11bd0ce28950.64.0"

# Load the file using EventAccumulator
event_acc = EventAccumulator(log_file)
event_acc.Reload()  # Load the log file

# List available tags (e.g., scalars, histograms)
print("Available tags:", event_acc.Tags())

# Extract scalar data
# scalars = event_acc.Scalars("tag_name")  # Replace 'tag_name' with your desired tag
# for scalar in scalars:
#     print(f"Step: {scalar.step}, Value: {scalar.value}, Wall Time: {scalar.wall_time}")
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/train', 'Distance/positive', 'Distance/negative', 'Metrics/loss_impacting_samples', 'Metrics/Hits_1/val', 'Metrics/Hits_3/val', 'Metrics/Hits_10/val', 'Metrics/MRR/val', 'Metrics/Hits_1/test', 'Metrics/Hits_3/test', 'Metrics/Hits_10/test', 'Metrics/MRR/test'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 14
#      11 print("Available tags:", event_acc.Tags())
#      13 # Extract scalar data
# ---> 14 scalars = event_acc.Scalars("tag_name")  # Replace 'tag_name' with your desired tag
#      15 for scalar in scalars:
#      16     print(f"Step: {scalar.step}, Value: {scalar.value}, Wall Time: {scalar.wall_time}")
#
# ...

# %%
! pip install tensorboard
# Out:
# ...
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# ...
# Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# ...
#    ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.4 MB 4.2 MB/s eta 0:00:01
#    --------- ------------------------------ 1.0/4.4 MB 2.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.3/4.4 MB 2.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.8/4.4 MB 2.3 MB/s eta 0:00:02
#    --------------------- ------------------ 2.4/4.4 MB 2.4 MB/s eta 0:00:01
# ...
